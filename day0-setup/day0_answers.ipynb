# %%
# Ensure the root directory is in the path for imports
import os
import sys

sys.path.append(os.path.dirname(os.path.dirname(os.path.realpath("/home/jonas/Desktop/aisb"))))
from aisb_utils import report

# Common imports
import requests
from typing import Callable

print("It works!")
# Out:
# It works!

# %%
from day0_test import test_prerequisites


# Run the prerequisite checks
test_prerequisites()
# Out:
# 🔧 AI Security Bootcamp - Prerequisites Check
# ==================================================
# ✅ Python 3.14.4 (OK)
# ✅ Docker installed
# ✅ Git: Git properly configured
# ✅ Python requirements are installed
#    SSH stderr: Hi jonasheschl! You've successfully authenticated, but GitHub does not provide shell access.
# ✅ GitHub SSH: GitHub SSH access working
#
# ==================================================
# 🎉 All prerequisites satisfied! You're ready for the bootcamp!
