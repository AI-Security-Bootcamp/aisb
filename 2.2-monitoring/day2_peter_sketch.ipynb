# %%
# %%
import os
import sys
from pathlib import Path

import nest_asyncio

__file__ = os.getcwd()

_root = next(p for p in Path(__file__).resolve().parents if (p / "aisb_utils").is_dir())
# day2_utils lives alongside this section (prompts/, logs/, reference_solutions/ too).
for _path in [str(_root), str(Path(__file__).resolve().parent)]:
    if _path not in sys.path:
        sys.path.insert(0, _path)

from aisb_utils.env import load_dotenv

load_dotenv()
nest_asyncio.apply()  # allow asyncio.run() inside Jupyter notebook cells

# This section's directory; prompts/, logs/, reference_solutions/ live here
SCRIPT_DIR = Path(__file__).resolve().parent
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 16
#      13     if _path not in sys.path:
#      14         sys.path.insert(0, _path)
# ---> 16 from aisb_utils.env import load_dotenv
#      18 load_dotenv()
#      19 nest_asyncio.apply()  # allow asyncio.run() inside Jupyter notebook cells
#
# File ~/www/aisb/aisb_utils/__init__.py:1
# ----> 1 from .test_utils import report
#       3 __all__ = ["report"]
#
# File ~/www/aisb/aisb_utils/test_utils.py:1
# ----> 1 from termcolor import colored
#       2 from typing import Callable
#       3 from functools import wraps
#
# ModuleNotFoundError: No module named 'termcolor'
